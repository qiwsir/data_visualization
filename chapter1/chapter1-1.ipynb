# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
a = np.linspace(0, 10, 100)
b = np.exp(-a)
plt.plot(a,  b)

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
a = np.linspace(0, 10, 100)
b = np.exp(-a)
ax.plot(a, b)

# %%
from numpy.random import normal,rand
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
x = normal(size=200)
ax.hist(x, bins=30)
# Out:
# (array([ 1.,  1.,  6.,  8.,  2.,  7.,  6.,  5.,  5.,  9., 11.,  6., 14.,
#          7., 15., 16., 16., 13.,  7.,  9.,  7.,  7.,  3.,  6.,  5.,  3.,
#          1.,  3.,  0.,  1.]),
#  array([-2.31564344, -2.15387546, -1.99210748, -1.8303395 , -1.66857151,
#         -1.50680353, -1.34503555, -1.18326757, -1.02149958, -0.8597316 ,
#         -0.69796362, -0.53619564, -0.37442765, -0.21265967, -0.05089169,
#          0.11087629,  0.27264428,  0.43441226,  0.59618024,  0.75794822,
#          0.91971621,  1.08148419,  1.24325217,  1.40502015,  1.56678814,
#          1.72855612,  1.8903241 ,  2.05209208,  2.21386007,  2.37562805,
#          2.53739603]),
#  <a list of 30 Patch objects>)
