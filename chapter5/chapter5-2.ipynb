# %%
import pandas as pd
from pyecharts import Geo

df = pd.read_csv("/Users/qiwsir/Documents/Codes/DataSet/pm25/pm2.csv")
city = df['CITY_NAME']
value = df['Exposed days']

geo = Geo("主要城市空气质量", "pm2.5", title_color = "#666666", title_pos = "center", 
          width=800, height=600, background_color = "#404a59")
geo.add("PM2.5", city, value, visual_range=[0, 300], visual_text_color='#fff', symbol_size=16, is_visualmap=True)
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="17196caf83b6444ab9a2e497ca7e9393" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_17196caf83b6444ab9a2e497ca7e9393 = echarts.init(document.getElementById('17196caf83b6444ab9a2e497ca7e9393'), 'light', {renderer: 'canvas'});
#
# var option_17196caf83b6444ab9a2e497ca7e9393 = {
#     "title": [
#         {
#             "text": "\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf",
#             "subtext": "pm2.5",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#666666",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2869501,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "PM2.5",
#             "coordinateSystem": "geo",
#             "symbol": "circle",
#             "symbolSize": 16,
#             "data": [
#                 {
#                     "name": "\u62c9\u8428",
#                     "value": [
#                         91.11,
#                         29.97,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "\u7389\u6eaa",
#                     "value": [
#                         102.52,
#                         24.35,
#                         7
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         8
#                     ]
#                 },
#                 {
#                     "name": "\u6cc9\u5dde",
#                     "value": [
#                         118.58,
#                         24.93,
#                         9
#                     ]
#                 },
#                 {
#                     "name": "\u6f33\u5dde",
#                     "value": [
#                         117.39,
#                         24.31,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u9f99\u5ca9",
#                     "value": [
#                         117.01,
#                         25.06,
#                         10
#                     ]
#                 },
#                 {
#                     "name": "\u6606\u660e",
#                     "value": [
#                         102.73,
#                         25.04,
#                         11
#                     ]
#                 },
#                 {
#                     "name": "\u8386\u7530",
#                     "value": [
#                         119.01,
#                         24.26,
#                         12
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5dde",
#                     "value": [
#                         119.3,
#                         26.08,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "\u4e09\u660e",
#                     "value": [
#                         117.36,
#                         26.13,
#                         16
#                     ]
#                 },
#                 {
#                     "name": "\u66f2\u9756",
#                     "value": [
#                         103.79,
#                         25.51,
#                         16
#                     ]
#                 },
#                 {
#                     "name": "\u9102\u5c14\u591a\u65af",
#                     "value": [
#                         109.781327,
#                         39.608266,
#                         18
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u5e73",
#                     "value": [
#                         118.1,
#                         26.38,
#                         18
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u5fb7",
#                     "value": [
#                         119.31,
#                         26.39,
#                         19
#                     ]
#                 },
#                 {
#                     "name": "\u4fdd\u5c71",
#                     "value": [
#                         99.1,
#                         25.08,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "\u6885\u5dde",
#                     "value": [
#                         116.1,
#                         24.55,
#                         24
#                     ]
#                 },
#                 {
#                     "name": "\u4e09\u4e9a",
#                     "value": [
#                         109.511909,
#                         18.252847,
#                         26
#                     ]
#                 },
#                 {
#                     "name": "\u6c55\u5c3e",
#                     "value": [
#                         115.375279,
#                         22.786211,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u53e3",
#                     "value": [
#                         110.35,
#                         20.02,
#                         28
#                     ]
#                 },
#                 {
#                     "name": "\u6986\u6797",
#                     "value": [
#                         109.47,
#                         38.18,
#                         28
#                     ]
#                 },
#                 {
#                     "name": "\u6f6e\u5dde",
#                     "value": [
#                         116.63,
#                         23.68,
#                         30
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u6e90",
#                     "value": [
#                         114.68,
#                         23.73,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "\u6e5b\u6c5f",
#                     "value": [
#                         110.359377,
#                         21.270708,
#                         32
#                     ]
#                 },
#                 {
#                     "name": "\u6500\u679d\u82b1",
#                     "value": [
#                         101.718637,
#                         26.582347,
#                         32
#                     ]
#                 },
#                 {
#                     "name": "\u60e0\u5dde",
#                     "value": [
#                         114.4,
#                         23.09,
#                         33
#                     ]
#                 },
#                 {
#                     "name": "\u821f\u5c71",
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         34
#                     ]
#                 },
#                 {
#                     "name": "\u6c55\u5934",
#                     "value": [

# %%
js = pd.read_csv("/Users/qiwsir/Documents/Codes/DataSet/jiangsu/city_population.csv")
js_cities = [name[:-1] for name in js.name]
js_cities
# Out:
# ['南京', '无锡', '徐州', '常州', '苏州', '南通', '连云港', '淮安', '盐城', '扬州', '镇江', '泰州', '宿迁']

# %%
jspm = df[df['CITY_NAME'].isin(js_cities)]

geo = Geo(
    "江苏城市空气质量",
    "",
    title_color="#202020",
    title_pos="center",
    width=800,
    height=600,
    background_color="#666666",
)

geo.add(
    "",
    jspm['CITY_NAME'],
    jspm['Exposed days'],
    maptype="江苏",
    type="effectScatter",
    is_random=True,
    effect_scale=5,
    is_legend_show=False,
)
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'jiangsu': '/nbextensions/echarts-china-provinces-js/jiangsu'
#         }
#     });
# </script>
#     <div id="03d3af06d1a84449ba92eb3b338fca25" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'jiangsu'], function(echarts) {
#
# var myChart_03d3af06d1a84449ba92eb3b338fca25 = echarts.init(document.getElementById('03d3af06d1a84449ba92eb3b338fca25'), 'light', {renderer: 'canvas'});
#
# var option_03d3af06d1a84449ba92eb3b338fca25 = {
#     "title": [
#         {
#             "text": "\u6c5f\u82cf\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#202020",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1653578,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5357\u901a",
#                     "value": [
#                         121.05,
#                         32.08,
#                         103
#                     ]
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": [
#                         120.62,
#                         31.32,
#                         109
#                     ]
#                 },
#                 {
#                     "name": "\u76d0\u57ce",
#                     "value": [
#                         120.13,
#                         33.38,
#                         114
#                     ]
#                 },
#                 {
#                     "name": "\u8fde\u4e91\u6e2f",
#                     "value": [
#                         119.16,
#                         34.59,
#                         120
#                     ]
#                 },
#                 {
#                     "name": "\u65e0\u9521",
#                     "value": [
#                         120.29,
#                         31.59,
#                         121
#                     ]
#                 },
#                 {
#                     "name": "\u626c\u5dde",
#                     "value": [
#                         119.42,
#                         32.39,
#                         123
#                     ]
#                 },
#                 {
#                     "name": "\u9547\u6c5f",
#                     "value": [
#                         119.44,
#                         32.2,
#                         124
#                     ]
#                 },
#                 {
#                     "name": "\u5e38\u5dde",
#                     "value": [
#                         119.95,
#                         31.79,
#                         125
#                     ]
#                 },
#                 {
#                     "name": "\u6cf0\u5dde",
#                     "value": [
#                         119.9,
#                         32.49,
#                         130
#                     ]
#                 },
#                 {
#                     "name": "\u6dee\u5b89",
#                     "value": [
#                         119.15,
#                         33.5,
#                         135
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         138
#                     ]
#                 },
#                 {
#                     "name": "\u5bbf\u8fc1",
#                     "value": [
#                         118.3,
#                         33.96,
#                         140
#                     ]
#                 },
#                 {
#                     "name": "\u5f90\u5dde",
#                     "value": [
#                         117.2,
#                         34.26,
#                         148
#                     ]
#                 }
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": false,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "backgroundColor": "#666666",
#     "animation": true,
#     "geo": {
#         "map": "\u6c5f\u82cf",
#         "roam": true,
#         "label": {
#             "emphasis": {
#                 "show": true,
#                 "textStyle": {
#                     "color": "#eee"
#                 }
#             }
#         },
#         "itemStyle": {
#             "normal": {
#                 "areaColor": "#323c48",
#                 "borderColor": "#111"
#             },
#             "emphasis": {
#                 "areaColor": "#2a333d"
#             }
#         }
#     },
#     "color": [
#         "#bda29a",
#         "#f47920",
#         "#749f83",
#         "#ca8622",
#         "#6e7074",
#         "#f6f5ec",
#         "#fab27b",
#         "#6d8346",
#         "#b2d235",
#         "#444693",
#         "#ac6767",
#         "#2f4554",
#         "#1d953f",
#         "#546570",
#         "#61a0a8",
#         "#d48265",
#         "#905a3d",
#         "#726930",
#         "#6950a1",
#         "#c4ccd3",
#         "#ef5b9c",
#         "#2a5caa",
#         "#c23531",
#         "#918597",
#         "#f05b72"
#     ]
# };
# myChart_03d3af06d1a84449ba92eb3b338fca25.setOption(option_03d3af06d1a84449ba92eb3b338fca25);
#
#     });
# </script>

# %%
hp = pd.read_csv("/Users/qiwsir/Documents/Codes/DataSet/house/houseprice.csv")
hp['mean'] = hp.mean(axis=1)
hp.drop(index=46, inplace=True)    # 有城市在默认安装的地图文件中没有，将其删除
geo = Geo("主要城市房产均价", "", title_color='#111111', width=800, height=600)
geo.add('PRICE', hp['city_name'], hp['mean'], 
        visual_range=[2000, 40000], symbol_size=20, 
        is_visualmap=True, type="heatmap")
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="bfb34ad36bb14fa18ecab1f7aae53128" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_bfb34ad36bb14fa18ecab1f7aae53128 = echarts.init(document.getElementById('bfb34ad36bb14fa18ecab1f7aae53128'), 'light', {renderer: 'canvas'});
#
# var option_bfb34ad36bb14fa18ecab1f7aae53128 = {
#     "title": [
#         {
#             "text": "\u4e3b\u8981\u57ce\u5e02\u623f\u4ea7\u5747\u4ef7",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#111111",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7214993,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "PRICE",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         35077.818181818184
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         30602.0
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         27390.18181818182
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         26639.88888888889
#                     ]
#                 },
#                 {
#                     "name": "\u4e09\u4e9a",
#                     "value": [
#                         109.511909,
#                         18.252847,
#                         17661.0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         17372.81818181818
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5dde",
#                     "value": [
#                         119.3,
#                         26.08,
#                         15330.777777777777
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         16818.545454545456
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         14533.181818181818
#                     ]
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": [
#                         120.33,
#                         36.07,
#                         13022.8
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         17551.636363636364
#                     ]
#                 },
#                 {
#                     "name": "\u4e49\u4e4c",
#                     "value": [
#                         120.06,
#                         29.32,
#                         12796.666666666666
#                     ]
#                 },
#                 {
#                     "name": "\u73e0\u6d77",
#                     "value": [
#                         113.52,
#                         22.3,
#                         13043.222222222223
#                     ]
#                 },
#                 {
#                     "name": "\u5b81\u6ce2",
#                     "value": [
#                         121.56,
#                         29.86,
#                         13609.777777777777
#                     ]
#                 },
#                 {
#                     "name": "\u6e29\u5dde",
#                     "value": [
#                         120.65,
#                         28.01,
#                         14248.4
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         9373.363636363636
#                     ]
#                 },
#                 {
#                     "name": "\u91d1\u534e",
#                     "value": [
#                         119.64,
#                         29.12,
#                         10260.8
#                     ]
#                 },
#                 {
#                     "name": "\u77f3\u5bb6\u5e84",
#                     "value": [
#                         114.48,
#                         38.03,
#                         9626.2
#                     ]
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": [
#                         117,
#                         36.65,
#                         9669.3
#                     ]
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": [
#                         120.62,
#                         31.32,
#                         10741.545454545454
#                     ]
#                 },
#                 {
#                     "name": "\u5eca\u574a",
#                     "value": [
#                         116.7,
#                         39.53,
#                         9234.666666666666
#                     ]
#                 },
#                 {
#                     "name": "\u4e1c\u839e",
#                     "value": [
#                         113.75,
#                         23.04,
#                         8587.888888888889
#                     ]
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": [
#                         117.27,
#                         31.86,
#                         8954.111111111111
#                     ]
#                 },
#                 {
#                     "name": "\u821f\u5c71",
#                     "value": [
#                         122.207216,
#                         29.985295,
#                         9569.25
#                     ]
#                 },
#                 {
#                     "name": "\u8386\u7530",
#                     "value": [
#                         119.01,
#                         24.26,
#                         9538.8
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u53e3",
#                     "value": [
#                         110.35,
#                         20.02,

# %%
some_cities = hp[hp['city_name'].isin(['上海', '苏州', "北京", "南京", '杭州', '广州'])]

from pyecharts import Line
years = ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
line = Line('选择几个城市的房价', width=800, height=600)
for city in some_cities['city_name']:
    line.add(city, years, some_cities[some_cities['city_name']==city][years].values[0])
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a6a20cc74cc0487d9647f0f682864ce0" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a6a20cc74cc0487d9647f0f682864ce0 = echarts.init(document.getElementById('a6a20cc74cc0487d9647f0f682864ce0'), 'light', {renderer: 'canvas'});
#
# var option_a6a20cc74cc0487d9647f0f682864ce0 = {
#     "title": [
#         {
#             "text": "\u9009\u62e9\u51e0\u4e2a\u57ce\u5e02\u7684\u623f\u4ef7",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6960344,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5317\u4eac",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2009",
#                     18741.0
#                 ],
#                 [
#                     "2010",
#                     24733.0
#                 ],
#                 [
#                     "2011",
#                     25166.0
#                 ],
#                 [
#                     "2012",
#                     30158.0
#                 ],
#                 [
#                     "2013",
#                     40342.0
#                 ],
#                 [
#                     "2014",
#                     37294.0
#                 ],
#                 [
#                     "2015",
#                     39437.0
#                 ],
#                 [
#                     "2016",
#                     57597.0
#                 ],
#                 [
#                     "2017",
#                     57768.0
#                 ],
#                 [
#                     "2018",
#                     54620.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6960344
#         },
#         {
#             "type": "line",
#             "name": "\u4e0a\u6d77",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2009",
#                     19810.0
#                 ],
#                 [
#                     "2010",
#                     22491.0
#                 ],
#                 [
#                     "2011",
#                     22665.0
#                 ],
#                 [
#                     "2012",
#                     23428.0
#                 ],
#                 [
#                     "2013",
#                     29978.0
#                 ],
#                 [
#                     "2014",
#                     30522.0
#                 ],
#                 [
#                     "2015",
#                     35237.0
#                 ],
#                 [
#                     "2016",
#                     52142.0
#                 ],
#                 [
#                     "2017",
#                     50017.0
#                 ],
#                 [
#                     "2018",
#                     50331.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6960344
#         },
#         {
#             "type": "line",
#             "name": "\u5e7f\u5dde",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "2009",
#                     9718.0
#                 ],
#                 [
#                     "2010",
#                     12944.0
#                 ],
#                 [
#                     "2011",
#                     14762.0
#                 ],
#                 [
#                     "2012",
#                     16555.0
#                 ],
#                 [
#                     "2013",
#                     19208.0
#                 ],
#                 [
#                     "2014",
#                     18564.0
#                 ],
#                 [
#                     "2015",
#                     20016.0
#                 ],
#                 [
#                     "2016",
#                     22926.0
#                 ],
#                 [
#                     "2017",
#                     27578.0
#                 ],
#                 [
#                     "2018",
#                     28825.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6960344
#         },
#         {
#             "type": "li

# %%
from pyecharts import GeoLines, Style

style = Style(title_color="#fff", title_pos="center", 
              width=800, height=600, background_color="#404a59")

data = [
    ["北京", "苏州"],
    ["北京", "哈尔滨"],
    ["北京", "呼和浩特"],
    ["北京", "乌鲁木齐"],
    ["北京", "西安"],
    ["北京", "广州"],
    ["北京", "贵州"],
    ["北京", "拉萨"]
]

geolines = GeoLines("直线图", **style.init_style)    #style.init_style表示使用前述style中的配置
geolines.add("BEIJING TO", data, is_legend_show=False)
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="20cbce5854f84e4296a070b7e844931b" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_20cbce5854f84e4296a070b7e844931b = echarts.init(document.getElementById('20cbce5854f84e4296a070b7e844931b'), 'light', {renderer: 'canvas'});
#
# var option_20cbce5854f84e4296a070b7e844931b = {
#     "title": [
#         {
#             "text": "\u76f4\u7ebf\u56fe",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5477907,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "lines",
#             "name": "BEIJING TO",
#             "zlevel": 2,
#             "effect": {
#                 "show": true,
#                 "period": 6,
#                 "trailLength": 0,
#                 "color": "#fff",
#                 "symbol": "circle",
#                 "symbolSize": 5
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u82cf\u5dde",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             120.62,
#                             31.32
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u54c8\u5c14\u6ee8",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             126.63,
#                             45.75
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u547c\u548c\u6d69\u7279",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             111.65,
#                             40.82
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u4e4c\u9c81\u6728\u9f50",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             87.68,
#                             43.77
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u897f\u5b89",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             108.95,
#                             34.27
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u5e7f\u5dde",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             113.23,
#                             23.16
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u8d35\u5dde",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             106.70741,
#                             26.598194
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u62c9\u8428",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             91.11,
#                             29.97
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "BEIJING TO",
#             "zlevel": 2,
#             "coordinateSystem": "geo",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": [
#                         120.62,
#                         31.32,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279",
#                     "value": [
#                         111.65,
#                         40.82,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u4e4c\u9c81\u6728\u9f50",
#                     "value": [
#                         87.68,
#                         43.77,
#                         0
#                     ]
#                 },

# %%
geolines_style = style.add(
    is_label_show = True,
    line_curve = 0.3,    # 设置线的弧度
    line_opacity = 0.6,
    legend_text_color = "#eee",
    legend_pos = "right",
    geo_effect_symbol = "plane",    # 线端的形状
    geo_effect_symbolsize = 16,
    label_color = ['#a6c84c', '#ffa022', '#46bee9'],
    label_pos = "right",
    label_formatter = "{b}",
    label_text_color = "#eee",
)

# %%
geolines = GeoLines("曲线", **style.init_style)
geolines.add("Beijing To", data, **geolines_style)
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="337745c5ce2143ecbc43cdacfb2c8b68" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_337745c5ce2143ecbc43cdacfb2c8b68 = echarts.init(document.getElementById('337745c5ce2143ecbc43cdacfb2c8b68'), 'light', {renderer: 'canvas'});
#
# var option_337745c5ce2143ecbc43cdacfb2c8b68 = {
#     "title": [
#         {
#             "text": "\u66f2\u7ebf",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4963135,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "lines",
#             "name": "Beijing To",
#             "zlevel": 2,
#             "effect": {
#                 "show": true,
#                 "period": 6,
#                 "trailLength": 0,
#                 "color": "#fff",
#                 "symbol": "path://M1705.06,1318.313v-89.254l-319.9-221.799l0.073-208.063c0.521-84.662-26.629-121.796-63.961-121.491c-37.332-0.305-64.482,36.829-63.961,121.491l0.073,208.063l-319.9,221.799v89.254l330.343-157.288l12.238,241.308l-134.449,92.931l0.531,42.034l175.125-42.917l175.125,42.917l0.531-42.034l-134.449-92.931l12.238-241.308L1705.06,1318.313z",
#                 "symbolSize": 16
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u82cf\u5dde",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             120.62,
#                             31.32
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u54c8\u5c14\u6ee8",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             126.63,
#                             45.75
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u547c\u548c\u6d69\u7279",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             111.65,
#                             40.82
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u4e4c\u9c81\u6728\u9f50",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             87.68,
#                             43.77
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u897f\u5b89",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             108.95,
#                             34.27
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u5e7f\u5dde",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             113.23,
#                             23.16
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u8d35\u5dde",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             106.70741,
#                             26.598194
#                         ]
#                     ]
#                 },
#                 {
#                     "fromName": "\u5317\u4eac",
#                     "toName": "\u62c9\u8428",
#                     "coords": [
#                         [
#                             116.407526,
#                             39.90403
#                         ],
#                         [
#                             91.11,
#                             29.97
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 0.6,
#                     "curveness": 0.3,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "Beijing To",
#             "zlevel": 2,
#             "coordinateSystem": "geo",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u82cf\u5dde",
#                     "value": [
#                         120.62,
#                         31.32,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": [
#                         126.63,
#                         45.75,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279",
#                     "value": [
#                         111.65,
#                         40.82,
#                         0
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,

# %%
import math
from pyecharts import Polar

data = []
for i in range(361):
    t = i / 180 * math.pi
    r = math.sin(2 * t) * math.cos(2 * t)
    data.append([r, i])
polar = Polar("极坐标", width=800, height=600)
polar.add("Flower", data, start_angle=0, symbol=None, axis_range=[0, None])
polar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1700f0f544a94232a4d625286240c847" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1700f0f544a94232a4d625286240c847 = echarts.init(document.getElementById('1700f0f544a94232a4d625286240c847'), 'light', {renderer: 'canvas'});
#
# var option_1700f0f544a94232a4d625286240c847 = {
#     "title": [
#         {
#             "text": "\u6781\u5750\u6807",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3401856,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Flower",
#             "coordinateSystem": "polar",
#             "symbol": "none",
#             "symbolSize": 4,
#             "data": [
#                 [
#                     0.0,
#                     0
#                 ],
#                 [
#                     0.03487823687206265,
#                     1
#                 ],
#                 [
#                     0.06958655048003272,
#                     2
#                 ],
#                 [
#                     0.10395584540887964,
#                     3
#                 ],
#                 [
#                     0.13781867790849958,
#                     4
#                 ],
#                 [
#                     0.17101007166283433,
#                     5
#                 ],
#                 [
#                     0.2033683215379001,
#                     6
#                 ],
#                 [
#                     0.2347357813929454,
#                     7
#                 ],
#                 [
#                     0.26495963211660245,
#                     8
#                 ],
#                 [
#                     0.2938926261462365,
#                     9
#                 ],
#                 [
#                     0.3213938048432697,
#                     10
#                 ],
#                 [
#                     0.3473291852294986,
#                     11
#                 ],
#                 [
#                     0.37157241273869707,
#                     12
#                 ],
#                 [
#                     0.394005376803361,
#                     13
#                 ],
#                 [
#                     0.41451878627752087,
#                     14
#                 ],
#                 [
#                     0.4330127018922193,
#                     15
#                 ],
#                 [
#                     0.44939702314958346,
#                     16
#                 ],
#                 [
#                     0.4635919272833937,
#                     17
#                 ],
#                 [
#                     0.4755282581475768,
#                     18
#                 ],
#                 [
#                     0.48514786313799824,
#                     19
#                 ],
#                 [
#                     0.492403876506104,
#                     20
#                 ],
#                 [
#                     0.4972609476841367,
#                     21
#                 ],
#                 [
#                     0.4996954135095479,
#                     22
#                 ],
#                 [
#                     0.4996954135095479,
#                     23
#                 ],
#                 [
#                     0.4972609476841367,
#                     24
#                 ],
#                 [
#                     0.49240387650610407,
#                     25
#                 ],
#                 [
#                     0.4851478631379983,
#                     26
#                 ],
#                 [
#                     0.4755282581475768,
#                     27
#                 ],
#                 [
#                     0.4635919272833937,
#                     28
#                 ],
#                 [
#                     0.44939702314958346,
#                     29
#                 ],
#                 [
#                     0.4330127018922194,
#                     30
#                 ],
#                 [
#                     0.41451878627752087,
#                     31
#                 ],
#                 [
#                     0.394005376803361,
#                     32
#                 ],
#                 [
#                     0.37157241273869723,
#                     33
#                 ],
#                 [
#                     0.34732918522949874,
#                     34
#                 ],
#                 [
#                     0.32139380484326974,
#                     35
#                 ],
#                 [
#                     0.29389262614623657,
#                     36
#                 ],
#                 [
#                     0.26495963211660245,
#                     37
#                 ],
#                 [
#                     0.23473578139294535,
#                     38
#                 ],
#                 [
#                     0.20336832153790002,
#                     39
#                 ],
#                 [
#                     0.1710100716628344,
#                     40
#                 ],
#                 [
#                     0.1378186779084996,
#                     41
#                 ],
#                 [
#                     0.10395584540887963,
#                     42
#                 ],
#                 [
#                     0.06958655048003265,
#                     43
#                 ],
#                 [
#                     0.03487823687206276,
#                     44
#                 ],
#                 [
#                     6.123233995736766e-17,
#                     45
#                 ],
#                 [
#                     -0.034878236872062415,
#                     46
#                 ],
#                 [
#                     -0.06958655048003276,
#                     47
#                 ],
#                 [
#                     -0.10395584540887953,
#                     48
#                 ],
#                 [
#                     -0.1378186779084993,
#                     49
#                 ],
#                 [
#                     -0.17101007166283433,
#                     50
#                 ],
#                 [
#                     -0.2033683215378999,
#                     51
#                 ],
#                 [
#                     -0.23473578139294524,
#                     52
#                 ],
#                 [
#                     -0.26495963211660234,
#                     53
#                 ],
#                 [
#                     -0.2938926261462365,
#                     54
#                 ],
#                 [
#                     -0.3213938048432697,
#                     55
#                 ],
#                 [
#                     -0.3473291852294987,
#                     56
#                 ],
#                 [
#                     -0.37157241273869707,
#                     57
#                 ],
#                 [
#                     -0.39400537680336106,
#                     58
#                 ],
#                 [
#                     -0.4145187862775207,
#                     59
#                 ],
#                 [
#                     -0.43301270189221924,
#                     60
#                 ],
#                 [
#                     -0.4493970231495834,
